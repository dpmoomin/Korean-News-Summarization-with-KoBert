# %% [markdown]
# # Mecab 로드

# %%
# !curl -s https://raw.githubusercontent.com/teddylee777/machine-learning/master/99-Misc/01-Colab/mecab-colab.sh | bash
from konlpy.tag import Mecab

mecab = Mecab()
mecab.morphs('동해물과 백두산이 마르고 닳도록')
# Out:
# --2022-04-09 15:11:25--  https://www.dropbox.com/s/9xls0tgtf3edgns/mecab-0.996-ko-0.9.2.tar.gz?dl=1
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.3.18, 2620:100:601b:18::a27d:812
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.3.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/dl/9xls0tgtf3edgns/mecab-0.996-ko-0.9.2.tar.gz [following]
# --2022-04-09 15:11:25--  https://www.dropbox.com/s/dl/9xls0tgtf3edgns/mecab-0.996-ko-0.9.2.tar.gz
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc198cd7bbdf592e5aa6d620247d.dl.dropboxusercontent.com/cd/0/get/BjFJ20kthU-3QPQetTuiFTpScQ_aHRbEkgF0cQA1F1t4SZrf6r6lhEmyZHzgzcl5gQKH93mqAHOSJ0BWZ8C6UPDqmRzmuABnLWBU7I6wEFhM3MNuyTDLtvwltBo6IfQWi9-tFXjDfuWFsqWDZ2j1ayqW133yJ39hFRpIkL58PU68Gb2zibhosSX1m-BcOEPFGlo/file?dl=1# [following]
# ...

# %% [markdown]
# # 패키지로드

# %%
# !pip install transformers
# !pip install tensorboardx
# Out:
# ...
#      |████████████████████████████████| 4.0 MB 5.5 MB/s
# ...
#      |████████████████████████████████| 77 kB 4.4 MB/s
# ...
#      |████████████████████████████████| 895 kB 38.3 MB/s
# ...
#      |████████████████████████████████| 596 kB 33.0 MB/s
# ...
#      |████████████████████████████████| 6.5 MB 36.1 MB/s
# ...
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ...
#      |████████████████████████████████| 125 kB 4.7 MB/s
# ...

# %% [markdown]
# # pyrouge

# %%
# !pip install pyrouge --upgrade
# !pip install https://github.com/bheinzerling/pyrouge/archive/master.zip
# !pip install pyrouge
# !pip show pyrouge
# !git clone https://github.com/andersjo/pyrouge.git
from pyrouge import Rouge155
# !pyrouge_set_rouge_path 'pyrouge/tools/ROUGE-1.5.5'
# Out:
# ...
#      |████████████████████████████████| 60 kB 3.0 MB/s
# ...
#   Created wheel for pyrouge: filename=pyrouge-0.1.3-py3-none-any.whl size=191621 sha256=b95c6c0f1bb450d1024775b75ea0f7463d7566fab93387cd622e25d2758b478f
#   Stored in directory: /root/.cache/pip/wheels/68/35/6a/ffb9a1f51b2b00fee42e7f67f5a5d8e10c67d048cda09ccd57
# Successfully built pyrouge
# ...
#      \ 202 kB 849 kB/s
# ...
# Name: pyrouge
# Version: 0.1.3
# Summary: A Python wrapper for the ROUGE summarization evaluation package.
# Home-page: https://github.com/noutenki/pyrouge
# Author: Benjamin Heinzerling, Anders Johannsen
# Author-email: benjamin.heinzerling@h-its.org
# License: LICENSE.txt
# Location: /usr/local/lib/python3.7/dist-packages
# Requires:
# Required-by:
# Cloning into 'pyrouge'...
# remote: Enumerating objects: 393, done.
# remote: Total 393 (delta 0), reused 0 (delta 0), pack-reused 393
# Receiving objects: 100% (393/393), 298.74 KiB | 2.99 MiB/s, done.
# Resolving deltas: 100% (109/109), done.
# ...

# %%
# !sudo apt-get install libxml-parser-perl
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   libauthen-sasl-perl libdata-dump-perl libencode-locale-perl
#   libfile-listing-perl libfont-afm-perl libhtml-form-perl libhtml-format-perl
#   libhtml-parser-perl libhtml-tagset-perl libhtml-tree-perl
#   libhttp-cookies-perl libhttp-daemon-perl libhttp-date-perl
#   libhttp-message-perl libhttp-negotiate-perl libio-html-perl
#   libio-socket-ssl-perl liblwp-mediatypes-perl liblwp-protocol-https-perl
#   libmailtools-perl libnet-http-perl libnet-smtp-ssl-perl libnet-ssleay-perl
#   libtimedate-perl libtry-tiny-perl liburi-perl libwww-perl
#   libwww-robotrules-perl netbase perl-openssl-defaults
# Suggested packages:
#   libdigest-hmac-perl libgssapi-perl libcrypt-ssleay-perl libauthen-ntlm-perl
# The following NEW packages will be installed:
#   libauthen-sasl-perl libdata-dump-perl libencode-locale-perl
# ...

# %%
# %%shell
# cd pyrouge/tools/ROUGE-1.5.5/data
# rm WordNet-2.0.exc.db # only if exist
# cd WordNet-2.0-Exceptions
# rm WordNet-2.0.exc.db # only if exist
#
# ./buildExeptionDB.pl . exc WordNet-2.0.exc.db
# cd ../
# ln -s WordNet-2.0-Exceptions/WordNet-2.0.exc.db WordNet-2.0.exc.db
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# indwelt
# inferred
# inferring
# initialled
# initialling
# inlaid
# insetting
# inspanned
# inspanning
# installed
# installing
# intensified
# interbred
# intercropped
# intercropping
# intercutting
# interlaid
# interlapped
# interlapping
# intermarried
# intermitted
# intermitting
# interpled
# interred
# interring
# interstratified
# interwove
# interwoven
# intromitted
# intromitting
# inwove
# inwoven
# inwrapped
# inwrapping
# is
# jabbed
# jabbing
# jagged
# jagging
# jammed
# jamming
# japanned
# japanning
# jarred
# jarring
# jellied
# jellified
# jemmied
# jerry-built
# jetted
# jetting
# jewelled
# jewelling
# jibbed
# jibbing
# jigged
# jigging
# jimmied
# jitterbugged
# jitterbugging
# jobbed
# jobbing
# jog-trotted
# jog-trotting
# jogged
# jogging
# joined_battle
# joined_forces
# joining_battle
# joining_forces
# joins_battle
# joins_forces
# jollied
# jollified
# jotted
# jotting
# joy-ridden
# joy-rode
# joypopped
# ...

# %% [markdown]
# # Load the Repo

# %%
# %cd /content
# !git clone https://github.com/HaloKim/KorBertSum.git
# %cd /content/KorBertSum
# Out:
# /content
# Cloning into 'KorBertSum'...
# remote: Enumerating objects: 11187, done.
# remote: Counting objects: 100% (10885/10885), done.
# remote: Compressing objects: 100% (7655/7655), done.
# remote: Total 11187 (delta 3289), reused 10780 (delta 3220), pack-reused 302
# Receiving objects: 100% (11187/11187), 18.99 MiB | 15.68 MiB/s, done.
# Resolving deltas: 100% (3464/3464), done.
# /content/KorBertSum

# %% [markdown]
# # BERT

# %%
from transformers import BertTokenizer, BertModel, BertConfig

config = BertConfig.from_pretrained('bert-base-multilingual-cased')
tokenizer = BertTokenizer.from_pretrained('bert-base-multilingual-cased')
model = BertModel.from_pretrained("bert-base-multilingual-cased")
# Out:
# Downloading:   0%|          | 0.00/625 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/972k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/29.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/681M [00:00<?, ?B/s]
# Some weights of the model checkpoint at bert-base-multilingual-cased were not used when initializing BertModel: ['cls.predictions.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# ...

# %% [markdown]
# # Data Package

# %%
import json

with open('/content/sample.jsonl', 'r') as json_file:
    json_list = list(json_file)
result = []
for json_str in json_list:
    result.append(json.loads(json_str))

# %%
import pandas as pd
df = pd.DataFrame(result)
df.head()
# Out:
#           id                                        abstractive  extractive  \
# 0  353465974  충주시는 민간보조사업의 증가와 보조금 집행관리에 대한 부당 행위가 증가함에따라 15...   [2, 3, 5]
# 1  366398381  국무조정실은 8일 오후 대전시청에서 '대전지역 규제혁신 현장간담회'를 열고 대전과 ...  [4, 6, 14]
# 2  360025161  중국 경제일간지 21세기경제보도는 중국 대형 생명보험사인 차이나라이프가 '차이나라이...   [0, 1, 2]
# 3  361884128   1일 대검찰청은 '조속한 검찰개혁 방안을 마련하라'는 문재인 대통령의 지시에 따라...   [4, 5, 3]
# 4  351452460  제주도가 민선 7기 출범과 함께 조직개편을 추진하면서 지난해 8월 공무원 정원을 2...  [6, 11, 7]
#
#                                     article_original  media
# 0  [보조금 집행 위법행위·지적사례 늘어, 특별감사반, 2017~2018년 축제 점검,...  충청투데이
# 1  [8일 대전시청에서 규제혁신 간담회, 도시개발 산업용지도 특화단지 지정가능, 국무조...   중도일보
# 2  [중국 경제일간지 21세기경제보도는 중국 대형 생명보험사인 차이나라이프(中國人壽)가...   내일신문
# 3  [전승표 기자, 대검, 文 지시에 발빠른 방안 마련 서울중앙지검 3곳 빼고 모두 폐...   기호일보
# 4  [제주도가 공무원 정원 102명 증원을 추진하고 있는 가운데 제주도청 조직 및 인력...   한라일보

# %%
test = df

# %%
test = df
test['morphs'] = 0
for i in range(len(test)):
  arr = []
  for j in test['article_original'][i]:
    arr.append(' '.join(mecab.morphs(j)))
  test['morphs'][i] = arr
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
test.to_csv('/content/output.csv')

# %% [markdown]
# # Load csv

# %%
import pandas as pd
import json

test = pd.read_csv('/content/output.csv').drop('Unnamed: 0', axis=1)
test.head()
# Out:
#           id                                        abstractive  extractive  \
# 0  353465974  충주시는 민간보조사업의 증가와 보조금 집행관리에 대한 부당 행위가 증가함에따라 15...   [2, 3, 5]
# 1  366398381  국무조정실은 8일 오후 대전시청에서 '대전지역 규제혁신 현장간담회'를 열고 대전과 ...  [4, 6, 14]
# 2  360025161  중국 경제일간지 21세기경제보도는 중국 대형 생명보험사인 차이나라이프가 '차이나라이...   [0, 1, 2]
# 3  361884128   1일 대검찰청은 '조속한 검찰개혁 방안을 마련하라'는 문재인 대통령의 지시에 따라...   [4, 5, 3]
# 4  351452460  제주도가 민선 7기 출범과 함께 조직개편을 추진하면서 지난해 8월 공무원 정원을 2...  [6, 11, 7]
#
#                                     article_original  media  \
# 0  ['보조금 집행 위법행위·지적사례 늘어', '특별감사반, 2017~2018년 축제 ...  충청투데이
# 1  ['8일 대전시청에서 규제혁신 간담회', '도시개발 산업용지도 특화단지 지정가능',...   중도일보
# 2  ['중국 경제일간지 21세기경제보도는 중국 대형 생명보험사인 차이나라이프(中國人壽)...   내일신문
# 3  ['전승표 기자', '대검, 文 지시에 발빠른 방안 마련 서울중앙지검 3곳 빼고 모...   기호일보
# 4  ['제주도가 공무원 정원 102명 증원을 추진하고 있는 가운데 제주도청 조직 및 인...   한라일보
#
#                                               morphs
# 0  ['보조금 집행 위법 행위 · 지적 사례 늘 어', '특별 감사 반 , 2017 ~...
# ...

# %%
from sklearn.model_selection import train_test_split

train_set, test_set = train_test_split(test, test_size = 0.2)
valid_set, test_set = train_test_split(test_set, test_size = 0.1)

# %% [markdown]
# # csv to json

# %%
import ast
from tqdm import tqdm
import os

list_dic = []
for idx, row in train_set.iterrows():
  raw = row['morphs']
  target_idx = ast.literal_eval(row['extractive'])

  sentences = raw.split(',')
  src = [i.split(' ') for i in sentences]
  tgt = [a for i,a in enumerate(src) if i in target_idx]
  
  mydict = {}
  mydict['src'] = src
  mydict['tgt'] = tgt
  list_dic.append(mydict)
        
temp = []
for i,a in enumerate(tqdm(list_dic)):
  if (i+1)%6!=0:
      temp.append(a)
  else:
      filename = 'korean.'+'train'+'.'+str(i//6)+'.json'
      with open('/content/KorBertSum'+'/json/'+filename, "w", encoding='utf-8') as json_file:
          json.dump(temp, json_file, ensure_ascii=False)
      temp = []
# Out:
# 100%|██████████| 2409/2409 [00:01<00:00, 2246.64it/s]

# %%
try:
  os.mkdir('/content/KorBertSum/json/val')
except:
  pass

list_dic = []
for idx, row in valid_set.iterrows():
        raw = row['morphs']
        target_idx = ast.literal_eval(row['extractive'])

        sentences = raw.split(',')
        src = [i.split(' ') for i in sentences]
        tgt = [a for i,a in enumerate(src) if i in target_idx]
        
        mydict = {}
        mydict['src'] = src
        mydict['tgt'] = tgt
        list_dic.append(mydict)
        
temp = []
for i,a in enumerate(tqdm(list_dic)):
    
    if (i+1)%6!=0:
        temp.append(a)
    else:
        filename = 'korean.'+'valid'+'.'+str(i//6)+'.json'
        with open('/content/KorBertSum'+'/json/val/'+filename, "w", encoding='utf-8') as json_file:
            json.dump(temp, json_file, ensure_ascii=False)
        temp = []
# Out:
# 100%|██████████| 542/542 [00:00<00:00, 1848.08it/s]

# %%
try:
  os.mkdir('/content/KorBertSum/json/test')
except:
  pass

list_dic = []
for idx, row in valid_set.iterrows():
        raw = row['morphs']
        target_idx = ast.literal_eval(row['extractive'])

        sentences = raw.split(',')
        src = [i.split(' ') for i in sentences]
        tgt = [a for i,a in enumerate(src) if i in target_idx]
        
        mydict = {}
        mydict['src'] = src
        mydict['tgt'] = tgt
        list_dic.append(mydict)
        
temp = []
for i,a in enumerate(tqdm(list_dic)):
    
    if (i+1)%6!=0:
        temp.append(a)
    else:
        filename = 'korean.'+'test'+'.'+str(i//6)+'.json'
        with open('/content/KorBertSum'+'/json/val/'+filename, "w", encoding='utf-8') as json_file:
            json.dump(temp, json_file, ensure_ascii=False)
        temp = []
# Out:
# 100%|██████████| 542/542 [00:00<00:00, 2261.10it/s]

# %% [markdown]
# # Json to pt

# %%
# 데이터 처리모드, json경로, 저장경로, 로그파일
# !python /content/KorBertSum/src/preprocess.py \
  -mode format_to_bert \
  -raw_path /content/KorBertSum/json \
  -save_path /content/KorBertSum/bert_data \
  -dataset train \
# Out:
# [('/content/KorBertSum/json/korean.train.167.json', Namespace(dataset='train', log_file='../../logs/cnndm.log', lower=True, map_path='../data/', max_nsents=100, max_src_ntokens=200, min_nsents=3, min_src_ntokens=5, mode='format_to_bert', n_cpus=2, oracle_mode='greedy', raw_path='/content/KorBertSum/json', save_path='/content/KorBertSum/bert_data', shard_size=2000), '/content/KorBertSum/bert_data/korean.train.167.bert.pt'), ('/content/KorBertSum/json/korean.train.394.json', Namespace(dataset='train', log_file='../../logs/cnndm.log', lower=True, map_path='../data/', max_nsents=100, max_src_ntokens=200, min_nsents=3, min_src_ntokens=5, mode='format_to_bert', n_cpus=2, oracle_mode='greedy', raw_path='/content/KorBertSum/json', save_path='/content/KorBertSum/bert_data', shard_size=2000), '/content/KorBertSum/bert_data/korean.train.394.bert.pt'), ('/content/KorBertSum/json/korean.train.346.json', Namespace(dataset='train', log_file='../../logs/cnndm.log', lower=True, map_path='../data/', m
# ...

# %%
try:
  os.mkdir('/content/KorBertSum/bert_data/val')
except:
  pass

# !python /content/KorBertSum/src/preprocess.py \
  -mode format_to_bert \
  -raw_path /content/KorBertSum/json/val \
  -save_path /content/KorBertSum/bert_data/test \
  -dataset valid \
# Out:
# [('/content/KorBertSum/json/val/korean.valid.10.json', Namespace(dataset='valid', log_file='../../logs/cnndm.log', lower=True, map_path='../data/', max_nsents=100, max_src_ntokens=200, min_nsents=3, min_src_ntokens=5, mode='format_to_bert', n_cpus=2, oracle_mode='greedy', raw_path='/content/KorBertSum/json/val', save_path='/content/KorBertSum/bert_data/test', shard_size=2000), '/content/KorBertSum/bert_data/test/korean.valid.10.bert.pt'), ('/content/KorBertSum/json/val/korean.valid.75.json', Namespace(dataset='valid', log_file='../../logs/cnndm.log', lower=True, map_path='../data/', max_nsents=100, max_src_ntokens=200, min_nsents=3, min_src_ntokens=5, mode='format_to_bert', n_cpus=2, oracle_mode='greedy', raw_path='/content/KorBertSum/json/val', save_path='/content/KorBertSum/bert_data/test', shard_size=2000), '/content/KorBertSum/bert_data/test/korean.valid.75.bert.pt'), ('/content/KorBertSum/json/val/korean.valid.14.json', Namespace(dataset='valid', log_file='../../logs/cnndm.log',
# ...

# %%
try:
  os.mkdir('/content/KorBertSum/bert_data/test')
except:
  pass

# !python /content/KorBertSum/src/preprocess.py \
  -mode format_to_bert \
  -raw_path /content/KorBertSum/json/test \
  -save_path /content/KorBertSum/bert_data/test \
  -dataset test \
# Out:
# []
# fin

# %% [markdown]
# # Train

# %%
# !python /content/KorBertSum/src/train.py \
  -mode train \
  -encoder classifier \
  -bert_data_path /content/KorBertSum/bert_data/korean \
  -model_path /content/KorBertSum/models/bert_classifier \
  -log_file /content/KorBertSum/logs/train.txt \
  -lr 2e-3 -visible_gpus 0 -gpu_ranks 0 -world_size 1 -report_every 1000 -dropout 0.5 \
  -save_checkpoint_steps 1000 -batch_size 3000 -decay_method noam -train_steps 5000 -accum_count 1\
# Out:
# [2022-04-09 16:41:19,169 INFO] Device ID 0
# [2022-04-09 16:41:19,169 INFO] Device cuda
# Traceback (most recent call last):
#   File "/content/KorBertSum/src/train.py", line 343, in <module>
#     train(args, device_id)
#   File "/content/KorBertSum/src/train.py", line 247, in train
#     torch.cuda.set_device(device_id)
#   File "/usr/local/lib/python3.7/dist-packages/torch/cuda/__init__.py", line 311, in set_device
#     torch._C._cuda_setDevice(device)
#   File "/usr/local/lib/python3.7/dist-packages/torch/cuda/__init__.py", line 214, in _lazy_init
#     torch._C._cuda_init()
# RuntimeError: No CUDA GPUs are available

# %% [markdown]
# # Validation

# %%
# %cd /content

# !python /content/KorBertSum/src/train.py \
  -mode validate \
  -bert_data_path /content/KorBertSum/bert_data/test/korean \
  -visible_gpus 0 -gpu_ranks 0 -batch_size 1000 \
  -log_file /content/KorBertSum/logs/val.txt \
  -temp_dir /content/KorBertSum/temp \
  -result_path /content/KorBertSum/results \
  -test_from /content/KorBertSum/models/bert_classifier/model_step_1000.pt \
# Out:
# /content
# Traceback (most recent call last):

# %% [markdown]
# # Test

# %%
# %cd /content

# !python /content/KorBertSum/src/train.py \
  -mode test \
  -bert_data_path /content/KorBertSum/bert_data/test/korean \
  -visible_gpus 0 -gpu_ranks 0 -batch_size 500 \
  -log_file /content/KorBertSum/logs/val.txt \
  -temp_dir /content/KorBertSum/temp \
  -result_path /content/KorBertSum/results \
  -test_from /content/KorBertSum/models/bert_classifier/model_step_1000.pt \
# Out:
# /content
# [2022-04-09 17:30:45,894 INFO] Loading checkpoint from /content/KorBertSum/models/bert_classifier/model_step_1000.pt
# Traceback (most recent call last):
#   File "/content/KorBertSum/src/train.py", line 356, in <module>
#     test(args, device_id, cp, step)
#   File "/content/KorBertSum/src/train.py", line 202, in test
#     checkpoint = torch.load(test_from, map_location=lambda storage, loc: storage)
#   File "/usr/local/lib/python3.7/dist-packages/torch/serialization.py", line 594, in load
#     with _open_file_like(f, 'rb') as opened_file:
#   File "/usr/local/lib/python3.7/dist-packages/torch/serialization.py", line 230, in _open_file_like
#     return _open_file(name_or_buffer, mode)
#   File "/usr/local/lib/python3.7/dist-packages/torch/serialization.py", line 211, in __init__
#     super(_open_file, self).__init__(open(name, mode))
# FileNotFoundError: [Errno 2] No such file or directory: '/content/KorBertSum/models/bert_classifier/model_step_1000.pt'
